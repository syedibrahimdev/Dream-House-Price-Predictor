# %%
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

df = pd.read_csv(r"E:\ibrahim\Portfolio Projects\House Price Prediction\data\processed\train_processed.csv")
df.head()

df = df.drop(df[(df['GrLivArea'] > 4000) & (df['SalePrice'] < 300000)].index)

no_feature_cols = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'MasVnrType', 
                   'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 
                   'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'
]

for col in no_feature_cols:
    df[col] = df[col].fillna('None')
    
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)

df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

for col in df.columns:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].mode()[0])

plt.figure(figsize=(8,5))
sns.scatterplot(x='GrLivArea', y='SalePrice', data=df)
plt.title("GrLivArea vs SalePrice — After Outlier Removal")
plt.show()

num_to_cat = ['MSSubClass', 'MoSold']
for col in num_to_cat:
    df[col] = df[col].astype(str)

df = pd.get_dummies(df, drop_first=True)
df.shape # (1458, 283)

print("Missing values after preprocessing:")
df.isna().sum().sum()

df.head()
"""
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Haris Ahmed\AppData\Local\Temp\ipykernel_19068\1753757348.py:1: SyntaxWarning: invalid escape sequence '\i'
#   """
# '\nimport pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom sklearn.preprocessing import StandardScaler\n\ndf = pd.read_csv(r"E:\\ibrahim\\Portfolio Projects\\House Price Prediction\\data\\processed\train_processed.csv")\ndf.head()\n\ndf = df.drop(df[(df[\'GrLivArea\'] > 4000) & (df[\'SalePrice\'] < 300000)].index)\n\nno_feature_cols = [\'PoolQC\', \'MiscFeature\', \'Alley\', \'Fence\', \'FireplaceQu\', \'MasVnrType\', \n                   \'GarageType\', \'GarageFinish\', \'GarageQual\', \'GarageCond\', \n                   \'BsmtQual\', \'BsmtCond\', \'BsmtExposure\', \'BsmtFinType1\', \'BsmtFinType2\'\n]\n\nfor col in no_feature_cols:\n    df[col] = df[col].fillna(\'None\')\n\ndf[\'MasVnrArea\'] = df[\'MasVnrArea\'].fillna(0)\ndf[\'GarageYrBlt\'] = df[\'GarageYrBlt\'].fillna(0)\n\ndf[\'LotFrontage\'] = df.groupby(\'Neighborhood\')[\'LotFrontage\'].transform(lambda x: x.fillna(x.median()))\n\nfor col in df.columns:\n    if df[col].isnull().sum() > 0:\n        df[col] = df[col].fillna(df[col].mode()[0])\n\nplt.figure(figsize=(8,5))\nsns.scatterplot(x=\'GrLivArea\', y=\'SalePrice\', data=df)\nplt.title("GrLivArea vs SalePrice — After Outlier Removal")\nplt.show()\n\nnum_to_cat = [\'MSSubClass\', \'MoSold\']\nfor col in num_to_cat:\n    df[col] = df[col].astype(str)\n\ndf = pd.get_dummies(df, drop_first=True)\ndf.shape # (1458, 283)\n\nprint("Missing values after preprocessing:")\ndf.isna().sum().sum()\n\ndf.head()\n'

# %%
"""
plt.figure(figsize=(12,5))
sns.histplot(df['SalePrice'], kde=True)
plt.show()

df['SalePrice'] = np.log1p(df['SalePrice'])

plt.figure(figsize=(12,5))
sns.histplot(df['SalePrice'], kde=True)
plt.show()

scaler = StandardScaler()
numeric_cols = df.select_dtypes(include=np.number).columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

df.to_csv(r"E:\ibrahim\Portfolio Projects\House Price Prediction\data\processed\train_processed.csv", index=False)
"""
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Haris Ahmed\AppData\Local\Temp\ipykernel_19068\1359156391.py:1: SyntaxWarning: invalid escape sequence '\i'
#   """
# '\nplt.figure(figsize=(12,5))\nsns.histplot(df[\'SalePrice\'], kde=True)\nplt.show()\n\ndf[\'SalePrice\'] = np.log1p(df[\'SalePrice\'])\n\nplt.figure(figsize=(12,5))\nsns.histplot(df[\'SalePrice\'], kde=True)\nplt.show()\n\nscaler = StandardScaler()\nnumeric_cols = df.select_dtypes(include=np.number).columns\ndf[numeric_cols] = scaler.fit_transform(df[numeric_cols])\n\ndf.to_csv(r"E:\\ibrahim\\Portfolio Projects\\House Price Prediction\\data\\processed\train_processed.csv", index=False)\n'
